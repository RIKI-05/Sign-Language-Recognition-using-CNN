# %%
import keras
import numpy as np
import pandas as pd
import cv2
from matplotlib import pyplot as plt
from keras.models import Sequential 
from keras.layers import Conv2D,MaxPooling2D, Dense,Flatten, Dropout
from keras.datasets import mnist 
import matplotlib.pyplot as plt
from keras.utils import np_utils
from keras.optimizers import SGD

# %%
train = pd.read_csv('train-Copy1.csv')
train
# Out:
#        label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0          3     107     118     127     134     139     143     146     150
# 1          6     155     157     156     156     156     157     156     158
# 2          2     187     188     188     187     187     186     187     188
# 3          2     211     211     212     212     211     210     211     210
# 4         13     164     167     170     172     176     179     180     184
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 27450     13     189     189     190     190     192     193     193     193
# 27451     23     151     154     157     158     160     161     163     164
# 27452     18     174     174     174     174     174     175     175     174
# 27453     17     177     181     184     185     187     189     190     191
# 27454     23     179     180     180     180     182     181     182     183
#
#        pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  \
# 0         153  ...       207       207       207       207       206
# 1         158  ...        69       149       128        87        94
# 2         187  ...       202       201       200       199       198
# 3         210  ...       235       234       233       231       230
# 4         185  ...        92       105       105       108       133
# ...       ...  ...       ...       ...       ...       ...       ...
# 27450     193  ...       132       165        99        77        52
# 27451     166  ...       198       198       198       198       198
# 27452     173  ...       121       196       209       208       206
# 27453     191  ...       119        56        27        58       102
# 27454     182  ...       108       132       170       194       214
#
#        pixel780  pixel781  pixel782  pixel783  pixel784
# 0           206       206       204       203       202
# 1           163       175       103       135       149
# 2           199       198       195       194       195
# 3           226       225       222       229       163
# 4           163       157       163       164       179
# ...         ...       ...       ...       ...       ...
# 27450       200       234       200       222       225
# 27451       196       195       195       195       194
# 27452       204       203       202       200       200
# 27453        79        47        64        87        93
# 27454       203       197       205       209       215
#
# [27455 rows x 785 columns]

# %%
test = pd.read_csv('test.csv')

# %%
y_train = train['label'].values
y_test = test['label'].values

X_train = train.drop(['label'],axis=1)
X_test = test.drop(['label'], axis=1)

X_train = np.array(X_train.iloc[:,:])
X_train = np.array([np.reshape(i, (28,28)) for i in X_train])

X_test = np.array(X_test.iloc[:,:])
X_test = np.array([np.reshape(i, (28,28)) for i in X_test])

num_classes = 26
y_train = np.array(y_train).reshape(-1)
y_test = np.array(y_test).reshape(-1)

y_train = np.eye(num_classes)[y_train]
y_test = np.eye(num_classes)[y_test]

# %%
X_train = X_train.reshape((27455, 28, 28, 1))
X_test = X_test.reshape((7172, 28, 28, 1))

# %%
classifier = Sequential()
classifier.add(Conv2D(filters=8, kernel_size=(3,3),strides=(1,1),padding='same',input_shape=(28,28,1),activation='relu', data_format='channels_last'))
classifier.add(MaxPooling2D(pool_size=(2,2)))
classifier.add(Conv2D(filters=16, kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'))
classifier.add(Dropout(0.5))
classifier.add(MaxPooling2D(pool_size=(4,4)))
classifier.add(Dense(128, activation='relu'))
classifier.add(Flatten())
classifier.add(Dense(26, activation='softmax'))
classifier.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
classifier.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
classifier.fit(X_train, y_train, epochs=50, batch_size=100)
# Out:
# Epoch 1/50
# 275/275 [==============================] - 13s 39ms/step - loss: 3.6014 - accuracy: 0.3370
# Epoch 2/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.9676 - accuracy: 0.6737
# Epoch 3/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.6180 - accuracy: 0.7871
# Epoch 4/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.4570 - accuracy: 0.8430
# Epoch 5/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.3714 - accuracy: 0.8722
# Epoch 6/50
# 275/275 [==============================] - 11s 41ms/step - loss: 0.3063 - accuracy: 0.8919
# Epoch 7/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.2619 - accuracy: 0.9085
# Epoch 8/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.2131 - accuracy: 0.9253
# Epoch 9/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.1872 - accuracy: 0.9335
# Epoch 10/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.1685 - accuracy: 0.9406
# Epoch 11/50
# 275/275 [==============================] - 11s 41ms/step - loss: 0.1668 - accuracy: 0.9439
# Epoch 12/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.1500 - accuracy: 0.9492
# Epoch 13/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.1330 - accuracy: 0.9545
# Epoch 14/50
# 275/275 [==============================] - 8s 29ms/step - loss: 0.1174 - accuracy: 0.9586
# Epoch 15/50
# 275/275 [==============================] - 5s 18ms/step - loss: 0.1130 - accuracy: 0.9618
# Epoch 16/50
# 275/275 [==============================] - 5s 18ms/step - loss: 0.1069 - accuracy: 0.9632
# Epoch 17/50
# 275/275 [==============================] - 5s 19ms/step - loss: 0.0932 - accuracy: 0.9674
# Epoch 18/50
# 275/275 [==============================] - 6s 21ms/step - loss: 0.1014 - accuracy: 0.9652
# Epoch 19/50
# 275/275 [==============================] - 6s 22ms/step - loss: 0.0936 - accuracy: 0.9688
# Epoch 20/50
# 275/275 [==============================] - 6s 21ms/step - loss: 0.0832 - accuracy: 0.9712
# Epoch 21/50
# 275/275 [==============================] - 6s 23ms/step - loss: 0.0846 - accuracy: 0.9718
# Epoch 22/50
# 275/275 [==============================] - 10s 36ms/step - loss: 0.0871 - accuracy: 0.9705
# Epoch 23/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.0782 - accuracy: 0.9734
# Epoch 24/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.0738 - accuracy: 0.9755
# Epoch 25/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.0673 - accuracy: 0.9773
# Epoch 26/50
# 275/275 [==============================] - 11s 42ms/step - loss: 0.0765 - accuracy: 0.9753
# Epoch 27/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.0615 - accuracy: 0.9797
# Epoch 28/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.0595 - accuracy: 0.9797
# Epoch 29/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.0534 - accuracy: 0.9817
# Epoch 30/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.0671 - accuracy: 0.9777
# Epoch 31/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.0589 - accuracy: 0.9801
# Epoch 32/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.0561 - accuracy: 0.9807
# Epoch 33/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.0569 - accuracy: 0.9822
# Epoch 34/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.0539 - accuracy: 0.9815
# Epoch 35/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.0584 - accuracy: 0.9811
# Epoch 36/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.0503 - accuracy: 0.9837
# Epoch 37/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.0505 - accuracy: 0.9840
# Epoch 38/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.0499 - accuracy: 0.9837
# Epoch 39/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.0599 - accuracy: 0.9808
# Epoch 40/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.0592 - accuracy: 0.9814
# Epoch 41/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.0446 - accuracy: 0.9855
# Epoch 42/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.0435 - accuracy: 0.9855
# Epoch 43/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.0436 - accuracy: 0.9858
# Epoch 44/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.0511 - accuracy: 0.9846
# Epoch 45/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.0544 - accuracy: 0.9831
# Epoch 46/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.0510 - accuracy: 0.9835
# Epoch 47/50
# 275/275 [==============================] - 11s 40ms/step - loss: 0.0454 - accuracy: 0.9854
# Epoch 48/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.0433 - accuracy: 0.9858
# Epoch 49/50
# 275/275 [==============================] - 11s 38ms/step - loss: 0.0456 - accuracy: 0.9849
# Epoch 50/50
# 275/275 [==============================] - 11s 39ms/step - loss: 0.0415 - accuracy: 0.9866

# %%
accuracy = classifier.evaluate(x=X_test,y=y_test,batch_size=32)
print("Accuracy: ",accuracy[1])
# Out:
# 225/225 [==============================] - 2s 9ms/step - loss: 0.2038 - accuracy: 0.9306
# Accuracy:  0.9305633306503296

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 8)         80
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 8)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 16)        1168
#
#  dropout (Dropout)           (None, 14, 14, 16)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 3, 3, 16)         0
#  2D)
#
#  dense (Dense)               (None, 3, 3, 128)         2176
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense_1 (Dense)             (None, 26)                29978
#
# =================================================================
# Total params: 33,402
# Trainable params: 33,402
# Non-trainable params: 0
# _________________________________________________________________

# %%
# from keras.utils.vis_utils import plot_model
from tensorflow.keras.utils import plot_model
# from plot_model import plot_model

# %%
plot_model(classifier, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
classifier.save('CNNmodel.h5')
